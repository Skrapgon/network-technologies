# %% [markdown]
# # Commands

# %% [markdown]
# ## Ping 3 different hosts on a local network

# %% [markdown]
# ![ping1.png](attachment:999b697d-1042-4e88-a41c-0842a294680b.png)
# ![ping2.png](attachment:4edbdd13-ac91-4ba6-9f00-e3795ee0ff3c.png)
# ![ping3.png](attachment:2863fa5a-9256-4643-b4ad-309c900c901e.png)

# %% [markdown]
# ## Get route to website

# %% [markdown]
# ![route_to_discord.png](attachment:5468add1-6d25-4618-9f6a-30627774d681.png)

# %% [markdown]
# ## All active devices. Scanning open device ports. Getting OS and services versions. Vulnerability scanning

# %% [markdown]
# ![all_devices.png](attachment:bbda7961-d8ec-4bd6-b059-96d836b57783.png)
# ![scanning_ports.png](attachment:1d211623-ea2a-46b4-bdd2-0ad531004a4d.png)
# ![OS_and_services_versions.png](attachment:084ffa69-123a-4eec-8943-2f43a957d1a1.png)
# ![security.png](attachment:ceb1e6b1-4097-4d2b-bad6-a42e96103f29.png)

# %% [markdown]
# ## Viewing open connections

# %% [markdown]
# ![active_connections_1.png](attachment:bc29d384-753e-4b44-95ea-8fe0259763de.png)
# ![active_connections_2.png](attachment:1270fc08-80e6-46bc-baaa-368209619c6e.png)

# %% [markdown]
# Processes ID (PID) with the largest number of connections (top 3):
# * 4
# * 6100
# * 16320

# %% [markdown]
# ## Traffic analysis

# %% [markdown]
# ### Beginning of trace
# ![image.png](attachment:3f364f90-e4dc-4bac-8b35-3b048ff020c3.png)
#
# ### End of trace
# ![trace_stop.png](attachment:334e2280-fe1e-426a-99e4-7cec9d925d89.png)
#
# ### Captured traffic protocols
# ![traffic.png](attachment:7249af1f-1582-4029-a1d5-168d88225312.png)
